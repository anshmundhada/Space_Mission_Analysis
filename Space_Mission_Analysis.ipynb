# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb

# %%
df=pd.read_csv('../DataSets/Space_Corrected.csv')
df
# Out:
#       Unnamed: 0.1  Unnamed: 0 Company Name  \
# 0                0           0       SpaceX
# 1                1           1         CASC
# 2                2           2       SpaceX
# 3                3           3    Roscosmos
# 4                4           4          ULA
# ...            ...         ...          ...
# 4319          4319        4319      US Navy
# 4320          4320        4320         AMBA
# 4321          4321        4321      US Navy
# 4322          4322        4322    RVSN USSR
# 4323          4323        4323    RVSN USSR
#
#                                                Location  \
# 0            LC-39A, Kennedy Space Center, Florida, USA
# 1     Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2                         Pad A, Boca Chica, Texas, USA
# 3          Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4              SLC-41, Cape Canaveral AFS, Florida, USA
# ...                                                 ...
# ...

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Company Name', 'Location', 'Datum',
#        'Detail', 'Status Rocket', ' Rocket', 'Status Mission'],
#       dtype='object')

# %%
df=df.drop('Unnamed: 0.1',axis=1)

# %%
df=df.drop('Unnamed: 0',axis=1)

# %%
df
# Out:
#      Company Name                                           Location  \
# 0          SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1            CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2          SpaceX                      Pad A, Boca Chica, Texas, USA
# 3       Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4             ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...           ...                                                ...
# 4319      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320         AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                            Datum  \
# 0     Fri Aug 07, 2020 05:12 UTC
# 1     Thu Aug 06, 2020 04:01 UTC
# 2     Tue Aug 04, 2020 23:57 UTC
# ...

# %%
df.isnull().sum()
# Out:
# Company Name         0
# Location             0
# Datum                0
# Detail               0
# Status Rocket        0
#  Rocket           3360
# Status Mission       0
# dtype: int64

# %%
df=df.rename(columns={' Rocket':'Price'})
df
# Out:
#      Company Name                                           Location  \
# 0          SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1            CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2          SpaceX                      Pad A, Boca Chica, Texas, USA
# 3       Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4             ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...           ...                                                ...
# 4319      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320         AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                            Datum  \
# 0     Fri Aug 07, 2020 05:12 UTC
# 1     Thu Aug 06, 2020 04:01 UTC
# 2     Tue Aug 04, 2020 23:57 UTC
# ...

# %%
df=df.rename(columns={'Detail':'Rocket'})
df
# Out:
#      Company Name                                           Location  \
# 0          SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1            CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2          SpaceX                      Pad A, Boca Chica, Texas, USA
# 3       Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4             ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...           ...                                                ...
# 4319      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320         AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                            Datum  \
# 0     Fri Aug 07, 2020 05:12 UTC
# 1     Thu Aug 06, 2020 04:01 UTC
# 2     Tue Aug 04, 2020 23:57 UTC
# ...

# %%
df.Price.unique()
# Out:
# array(['50.0 ', '29.75 ', nan, '65.0 ', '145.0 ', '64.68 ', '48.5 ',
#        '90.0 ', '46.0 ', '28.3 ', '29.15 ', '7.5 ', '30.8 ', '5.3 ',
#        '12.0 ', '112.5 ', '120.0 ', '153.0 ', '200.0 ', '85.0 ', '115.0 ',
#        '41.8 ', '21.0 ', '31.0 ', '40.0 ', '164.0 ', '62.0 ', '37.0 ',
#        '350.0 ', '39.0 ', '47.0 ', '35.0 ', '69.7 ', '109.0 ', '45.0 ',
#        '123.0 ', '130.0 ', '25.0 ', '56.5 ', '15.0 ', '29.0 ', '80.0 ',
#        '140.0 ', '55.0 ', '59.5 ', '450.0 ', '7.0 ', '20.14 ', '133.0 ',
#        '190.0 ', '135.0 ', '20.0 ', '136.6 ', '5,000.0 ', '1,160.0 ',
#        '59.0 ', '63.23 '], dtype=object)

# %%
df.Price=df.Price.replace('[,]','',regex=True)

# %%
df['Price']=pd.to_numeric(df['Price'])

# %%
df['Price']=df['Price'].fillna(df['Price'].median())

# %%
df
# Out:
#      Company Name                                           Location  \
# 0          SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1            CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2          SpaceX                      Pad A, Boca Chica, Texas, USA
# 3       Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4             ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...           ...                                                ...
# 4319      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320         AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                            Datum  \
# 0     Fri Aug 07, 2020 05:12 UTC
# 1     Thu Aug 06, 2020 04:01 UTC
# 2     Tue Aug 04, 2020 23:57 UTC
# ...

# %%
df.dtypes
# Out:
# Company Name       object
# Location           object
# Datum              object
# Rocket             object
# Status Rocket      object
# Price             float64
# Status Mission     object
# dtype: object

# %%
df['Datum']=pd.to_datetime(df['Datum'],errors='coerce')

# %%
df
# Out:
#      Company Name                                           Location  \
# 0          SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1            CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2          SpaceX                      Pad A, Boca Chica, Texas, USA
# 3       Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4             ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...           ...                                                ...
# 4319      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320         AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                          Datum                                        Rocket  \
# ...

# %%
df['Year']=df['Datum'].dt.year

# %%
df['Month']=df['Datum'].dt.month

# %%
df
# Out:
#      Company Name                                           Location  \
# 0          SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1            CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2          SpaceX                      Pad A, Boca Chica, Texas, USA
# 3       Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4             ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...           ...                                                ...
# 4319      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320         AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321      US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323    RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                          Datum                                        Rocket  \
# ...

# %%
df.describe()
# Out:
#              Price         Year        Month
# count  4324.000000  4198.000000  4198.000000
# mean     82.464311  1987.455693     6.741782
# std     141.402481    18.085370     3.416107
# min       5.300000  1957.000000     1.000000
# 25%      62.000000  1972.000000     4.000000
# 50%      62.000000  1985.000000     7.000000
# 75%      62.000000  2002.000000    10.000000
# max    5000.000000  2020.000000    12.000000

# %%
df=df.rename(columns={'Company Name':'CompanyName'})

# %%
df=df.rename(columns={'Status Rocket':'StatusRocket'})

# %%
df=df.rename(columns={'Status Mission':'StatusMission'})

# %%
df
# Out:
#      CompanyName                                           Location  \
# 0         SpaceX         LC-39A, Kennedy Space Center, Florida, USA
# 1           CASC  Site 9401 (SLS-2), Jiuquan Satellite Launch Ce...
# 2         SpaceX                      Pad A, Boca Chica, Texas, USA
# 3      Roscosmos       Site 200/39, Baikonur Cosmodrome, Kazakhstan
# 4            ULA           SLC-41, Cape Canaveral AFS, Florida, USA
# ...          ...                                                ...
# 4319     US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4320        AMBA           LC-26A, Cape Canaveral AFS, Florida, USA
# 4321     US Navy           LC-18A, Cape Canaveral AFS, Florida, USA
# 4322   RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
# 4323   RVSN USSR          Site 1/5, Baikonur Cosmodrome, Kazakhstan
#
#                          Datum                                        Rocket  \
# ...

# %%
df.CompanyName.value_counts()
# Out:
# CompanyName
# RVSN USSR           1777
# Arianespace          279
# CASC                 251
# General Dynamics     251
# NASA                 203
# VKS RF               201
# US Air Force         161
# ULA                  140
# Boeing               136
# Martin Marietta      114
# SpaceX               100
# MHI                   84
# Northrop              83
# Lockheed              79
# ISRO                  76
# Roscosmos             55
# ILS                   46
# Sea Launch            36
# ISAS                  30
# Kosmotras             22
# US Navy               17
# ISA                   13
# Rocket Lab            13
# Eurockot              13
# ESA                   13
# Blue Origin           12
# IAI                   11
# ExPace                10
# ASI                    9
# CNES                   8
# AMBA                   8
# MITT                   7
# JAXA                   7
# Land Launch            7
# UT                     5
# KCST                   5
# ...

# %%
df.StatusMission.value_counts()
# Out:
# StatusMission
# Success              3879
# Failure               339
# Partial Failure       102
# Prelaunch Failure       4
# Name: count, dtype: int64

# %%
df.StatusRocket.value_counts()
# Out:
# StatusRocket
# StatusRetired    3534
# StatusActive      790
# Name: count, dtype: int64

# %%
df.Rocket.value_counts()
# Out:
# Rocket
# Cosmos-3MRB (65MRB) | BOR-5 Shuttle    6
# Lambda-IV S | Osumi                    5
# Titan IV(402)B | DSP                   5
# Titan IIID | KH-11                     5
# Proton K/Block D | Zond                4
#                                       ..
# Ariane 44P | Intelsat 709              1
# Ariane 5 G | Cluster                   1
# Delta II 7925 | Galaxy 9               1
# Space Shuttle Endeavour | STS-77       1
# Sputnik 8K71PS | Sputnik-1             1
# Name: count, Length: 4278, dtype: int64

# %%
df.Location.value_counts()
# Out:
# Location
# Site 31/6, Baikonur Cosmodrome, Kazakhstan               235
# Site 132/1, Plesetsk Cosmodrome, Russia                  216
# Site 43/4, Plesetsk Cosmodrome, Russia                   202
# Site 41/1, Plesetsk Cosmodrome, Russia                   198
# Site 1/5, Baikonur Cosmodrome, Kazakhstan                193
#                                                         ...
# Jiuquan Satellite Launch Center, China                     1
# LP-41, Kauai, Pacific Missile Range Facility               1
# Tai Rui Barge, Yellow Sea                                  1
# Launch Plateform, Shahrud Missile Test Site                1
# K-496 Submarine, Barents Sea Launch Area, Barents Sea      1
# Name: count, Length: 137, dtype: int64

# %%
sb.histplot(df.Price,bins=15)
plt.show()

# %%
sb.boxplot(df.Year)
plt.show()

# %%
sb.boxplot(df.Month)
plt.show()

# %% [markdown]
# # Top Agencies Analysis:

# %%
df.CompanyName.value_counts().nlargest(10)
# Out:
# CompanyName
# RVSN USSR           1777
# Arianespace          279
# CASC                 251
# General Dynamics     251
# NASA                 203
# VKS RF               201
# US Air Force         161
# ULA                  140
# Boeing               136
# Martin Marietta      114
# Name: count, dtype: int64

# %%
df[df['StatusMission']=='Success'].groupby('CompanyName').size()
# Out:
# CompanyName
# AMBA                   4
# ASI                    9
# Arianespace          269
# Arm??e de l'Air        3
# Blue Origin           12
# Boeing               131
# CASC                 231
# CASIC                  3
# CECLES                 1
# CNES                   6
# Douglas                1
# ESA                    9
# Eurockot              12
# ExPace                 9
# General Dynamics     203
# IAI                    9
# ILS                   45
# IRGC                   1
# ISA                    4
# ISAS                  26
# ISRO                  63
# JAXA                   6
# KARI                   1
# KCST                   2
# Khrunichev             1
# Kosmotras             21
# Land Launch            6
# Lockheed              74
# MHI                   80
# MITT                   6
# Martin Marietta      100
# NASA                 186
# Northrop              74
# OKB-586                2
# RAE                    1
# RVSN USSR           1614
# ...

# %%
df['Location'].value_counts()
# Out:
# Location
# Site 31/6, Baikonur Cosmodrome, Kazakhstan               235
# Site 132/1, Plesetsk Cosmodrome, Russia                  216
# Site 43/4, Plesetsk Cosmodrome, Russia                   202
# Site 41/1, Plesetsk Cosmodrome, Russia                   198
# Site 1/5, Baikonur Cosmodrome, Kazakhstan                193
#                                                         ...
# Jiuquan Satellite Launch Center, China                     1
# LP-41, Kauai, Pacific Missile Range Facility               1
# Tai Rui Barge, Yellow Sea                                  1
# Launch Plateform, Shahrud Missile Test Site                1
# K-496 Submarine, Barents Sea Launch Area, Barents Sea      1
# Name: count, Length: 137, dtype: int64

# %%
df[df['StatusMission']=='Success'].groupby('Location').size()
# Out:
# Location
# Blue Origin Launch Site, West Texas, Texas, USA       12
# Brigitte, Hammaguir, Algeria, France                   3
# ELA-1, Guiana Space Centre, French Guiana, France     12
# ELA-2, Guiana Space Centre, French Guiana, France    115
# ELA-3, Guiana Space Centre, French Guiana, France    104
#                                                     ...
# Svobodny Cosmodrome, Russia                            5
# Tai Rui Barge, Yellow Sea                              1
# Taiyuan Satellite Launch Center, China                 5
# Uchinoura Space Center, Japan                          2
# Xichang Satellite Launch Center, China                 1
# Length: 128, dtype: int64

# %%
a=df['Rocket'].value_counts().nlargest(10)

# %%
sb.countplot(x=a)
plt.show()

# %%
df['StatusRocket'].value_counts()
# Out:
# StatusRocket
# StatusRetired    3534
# StatusActive      790
# Name: count, dtype: int64

# %%
sb.barplot(df.StatusRocket)
plt.show()

# %% [markdown]
# # Cost Analysis:

# %%
df[['CompanyName','Price']].groupby('CompanyName').mean()
# Out:
#                        Price
# CompanyName
# AEB                62.000000
# AMBA               62.000000
# ASI                62.000000
# Arianespace        99.250896
# Arm??e de l'Air    62.000000
# Blue Origin        62.000000
# Boeing             67.933824
# CASC               48.232112
# CASIC              62.000000
# CECLES             62.000000
# CNES               62.000000
# Douglas            62.000000
# EER                20.000000
# ESA                60.076923
# Eurockot           41.800000
# ExPace             58.630000
# Exos               62.000000
# General Dynamics   62.000000
# IAI                62.000000
# ILS                73.173913
# IRGC               62.000000
# ISA                62.000000
# ISAS               62.000000
# ISRO               35.986842
# JAXA               59.428571
# KARI               62.000000
# KCST               62.000000
# Khrunichev         62.000000
# Kosmotras          29.000000
# Land Launch        62.000000
# ...

# %%
df[df['StatusMission']=='Success']['Rocket'].value_counts()
# Out:
# Rocket
# Cosmos-3MRB (65MRB) | BOR-5 Shuttle    6
# Titan IIID | KH-11                     5
# Titan IIID | KH-9                      4
# Titan IV(402)B | DSP                   4
# Cosmos-3MRB (65MRB) | BOR-2 Shuttle    4
#                                       ..
# Space Shuttle Atlantis | STS-84        1
# Molniya-M /Block 2BL | Cosmos 2342     1
# Long March 3A | ChinaSat 6             1
# Delta II 7920-10C | MS-1               1
# Sputnik 8K71PS | Sputnik-1             1
# Name: count, Length: 3846, dtype: int64

# %%
df[df['StatusMission']=='Success']['Price'].mean()
# Out:
# np.float64(84.41596803299821)

# %% [markdown]
# # Temporal analysis:

# %%
df['Year'].value_counts().sort_index()
# Out:
# Year
# 1957.0      3
# 1958.0     22
# 1959.0     20
# 1960.0     38
# 1961.0     52
#          ...
# 2016.0     88
# 2017.0     90
# 2018.0    117
# 2019.0    107
# 2020.0     63
# Name: count, Length: 64, dtype: int64

# %%
sb.lineplot(x=df.Year,y=df.Price)
plt.title('Year vs Price')
plt.show()

# %% [markdown]
# #### -Mission Outcome Trend Over Time

# %%
df.groupby(['Year','StatusMission']).size()
# Out:
# Year    StatusMission
# 1957.0  Failure              1
#         Success              2
# 1958.0  Failure             14
#         Partial Failure      2
#         Success              6
#                           ...
# 2019.0  Failure              5
#         Partial Failure      2
#         Success            100
# 2020.0  Failure              6
#         Success             57
# Length: 175, dtype: int64

# %%
sb.barplot(x=df.StatusMission,y=df.Year)
plt.show()
